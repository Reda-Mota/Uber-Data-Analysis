# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#print(plt.style.available)

# %%
#Cleaning Data


df=pd.read_csv("ncr_ride_bookings.csv")
pd.set_option('display.max_columns', 21)

df['DateTime']= pd.to_datetime(df['Date']+' '+df['Time'])
df.drop(columns =['Date', 'Time'], inplace=True)

df['Reason for cancelling by Customer'] = df['Reason for cancelling by Customer'].fillna("Not Added")
df['Driver Cancellation Reason'] = df['Driver Cancellation Reason'].fillna("Not Added")
df = df.fillna('Not added')

cols_to_clean = ['Booking ID', 'Customer ID', 'Vehicle Type']
for col in cols_to_clean:
    df[col] = df[col].str.replace('"', '').str.strip()

# %%
df
# Out:
#         Booking ID   Booking Status Customer ID   Vehicle Type  \
# 0       CNR5884300  No Driver Found  CID1982111          eBike
# 1       CNR1326809       Incomplete  CID4604802       Go Sedan
# 2       CNR8494506        Completed  CID9202816           Auto
# 3       CNR8906825        Completed  CID2610914  Premier Sedan
# 4       CNR1950162        Completed  CID9933542           Bike
# ...            ...              ...         ...            ...
# 149995  CNR6500631        Completed  CID4337371        Go Mini
# 149996  CNR2468611        Completed  CID2325623        Go Mini
# 149997  CNR6358306        Completed  CID9925486       Go Sedan
# 149998  CNR3030099        Completed  CID9415487           Auto
# 149999  CNR3447390        Completed  CID4108667  Premier Sedan
#
#                Pickup Location      Drop Location   Avg VTAT   Avg CTAT  \
# 0                  Palam Vihar            Jhilmil  Not added  Not added
# 1                Shastri Nagar  Gurgaon Sector 56        4.9       14.0
# 2                      Khandsa      Malviya Nagar       13.4       25.8
# 3          Central Secretariat           Inderlok       13.1       28.5
# 4             Ghitorni Village        Khan Market        5.3       19.6
# ...                        ...                ...        ...        ...
# 149995                 MG Road           Ghitorni       10.2       44.4
# 149996        Golf Course Road         Akshardham        5.1       30.8
# 149997  Satguru Ram Singh Marg           Jor Bagh        2.7       23.4
# 149998               Ghaziabad         Saidulajab        6.9       39.6
# 149999         Ashok Park Main  Gurgaon Sector 29        3.5       33.7
#
#        Cancelled Rides by Customer Reason for cancelling by Customer  \
# 0                        Not added                         Not Added
# 1                        Not added                         Not Added
# 2                        Not added                         Not Added
# 3                        Not added                         Not Added
# 4                        Not added                         Not Added
# ...                            ...                               ...
# 149995                   Not added                         Not Added
# 149996                   Not added                         Not Added
# 149997                   Not added                         Not Added
# 149998                   Not added                         Not Added
# 149999                   Not added                         Not Added
#
#        Cancelled Rides by Driver Driver Cancellation Reason Incomplete Rides  \
# 0                      Not added                  Not Added        Not added
# 1                      Not added                  Not Added              1.0
# 2                      Not added                  Not Added        Not added
# 3                      Not added                  Not Added        Not added
# 4                      Not added                  Not Added        Not added
# ...                          ...                        ...              ...
# 149995                 Not added                  Not Added        Not added
# 149996                 Not added                  Not Added        Not added
# 149997                 Not added                  Not Added        Not added
# 149998                 Not added                  Not Added        Not added
# 149999                 Not added                  Not Added        Not added
#
#        Incomplete Rides Reason Booking Value Ride Distance Driver Ratings  \
# 0                    Not added     Not added     Not added      Not added
# 1            Vehicle Breakdown         237.0          5.73      Not added
# 2                    Not added         627.0         13.58            4.9
# 3                    Not added         416.0         34.02            4.6
# 4                    Not added         737.0         48.21            4.1
# ...                        ...           ...           ...            ...
# 149995               Not added         475.0         40.08            3.7
# 149996               Not added        1093.0         21.31            4.8
# 149997               Not added         852.0         15.93            3.9
# 149998               Not added         333.0         45.54            4.1
# 149999               Not added         806.0         21.19            4.6
#
#        Customer Rating Payment Method            DateTime
# 0            Not added      Not added 2024-03-23 12:29:38
# 1            Not added            UPI 2024-11-29 18:01:39
# 2                  4.9     Debit Card 2024-08-23 08:56:10
# 3                  5.0            UPI 2024-10-21 17:17:25
# 4                  4.3            UPI 2024-09-16 22:08:00
# ...                ...            ...                 ...
# 149995             4.1    Uber Wallet 2024-11-11 19:34:01
# 149996             5.0            UPI 2024-11-24 15:55:09
# 149997             4.4           Cash 2024-09-18 10:55:15
# 149998             3.7            UPI 2024-10-05 07:53:34
# 149999             4.9    Credit Card 2024-03-10 15:38:03
#
# [150000 rows x 20 columns]

# %%
#Revenue Analysis by Vehicle Type
#Objective: Identify which vehicle category generates the highest revenue for the company.

df['Booking Value'] = pd.to_numeric(df['Booking Value'], errors='coerce')
care_value = df.groupby('Vehicle Type')['Booking Value'].sum()
care_value.sort_values(ascending=False)
# Out:
# Vehicle Type
# Auto             12878422.0
# Go Mini          10338496.0
# Go Sedan          9369719.0
# Bike              7837697.0
# Premier Sedan     6275332.0
# eBike             3618485.0
# Uber XL           1528032.0
# Name: Booking Value, dtype: float64

# %%
#visualisation of Revenue Analysis by Vehicle Type

plt.figure(figsize=(7,4))
plt.barh(care_value.index , care_value.values)
plt.title('The most Profitable Cars')
plt.xlabel('Booking Value')
plt.ylabel('Cars')
plt.grid(True)
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Profitibale Cars')

# %%
#Peak Hour Analysis (Rush Hours)
#Objective: Determine the time of day with the highest ride demand to optimize driver availability.

df['Hour'] = df['DateTime'].dt.hour
hourly_counts = df['Hour'].value_counts().sort_index()

# %%
#Visualisation Peak Hour Analysis (Rush Hours)
plt.figure(figsize=(12, 6))
hourly_counts.plot(kind='line', marker='o', color='#8E44AD', linewidth=2)
plt.title('Rush Hour Analysis')
plt.xlabel('Hours of day')
plt.ylabel('Number of trips')
plt.grid(True)
plt.xticks(range(0, 24)) 
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Rush Hour')

# %%
df['Booking Status'].value_counts(normalize =True)
# Out:
# Booking Status
# Completed                0.62
# Cancelled by Driver      0.18
# No Driver Found          0.07
# Cancelled by Customer    0.07
# Incomplete               0.06
# Name: proportion, dtype: float64

# %%
Booking_Satatus = df['Booking Status'].value_counts()


plt.barh(Booking_Satatus.index , Booking_Satatus.values, color ='springgreen')
plt.title('Cancellation Forensics')
plt.xlabel('Number of Booking')
plt.grid(True)
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Cancellation Foresics')

# %%
#Driver Cancellation Forensics
#Objective: Investigate the primary reasons why drivers cancel trips.

df['Driver Cancellation Reason'].value_counts()
# Out:
# Driver Cancellation Reason
# Not Added                              123000
# Customer related issue                   6837
# The customer was coughing/sick           6751
# Personal & Car related issues            6726
# More than permitted people in there      6686
# Name: count, dtype: int64

# %%
#Geospatial Analysis: Top Pickup Locations
#Objective: Identify the top 10 hotspots where customers request rides the most.

Pickup_localisation = df['Pickup Location'].value_counts().head(10)

plt.barh(Pickup_localisation.index , Pickup_localisation.values, color ='sienna')
plt.title('Most 10 Pickup Localistion')
plt.xlabel('Number of Booking')
plt.ylabel('Localistion')
plt.grid(True)
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Pickup Localistion')

# %%
#Route Analysis: The Golden Routes
#Objective: Discover the most popular travel routes (Origin → Destination).

df['Route'] =df['Pickup Location'] + ' => ' +df['Drop Location']
Route = df['Route'].value_counts().head()

plt.barh(Route.index , Route.values, color ='royalblue')
plt.title('The 5 Golden Routes')
plt.xlabel('Number of Booking')
plt.ylabel('Routes')
plt.grid(True)
plt.style.use('fivethirtyeight')
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Golden Routes')

# %%
#Pricing Efficiency: Average Price Per KM
#Objective: Compare the cost efficiency of different vehicle types.

df['Price_Per_KM']=df['Booking Value']/df['Ride Distance']
df.groupby('Vehicle Type')['Price_Per_KM'].mean()q
# Out:
# Vehicle Type
# Auto             38.085136
# Bike             38.168779
# Go Mini          37.642931
# Go Sedan          38.22088
# Premier Sedan    37.855816
# Uber XL          37.932004
# eBike            36.314851
# Name: Price_Per_KM, dtype: object

# %%
#Correlation Heatmap: Price vs. Distance
#Objective: Visualize the strength of the relationship between trip distance and trip cost.

df['Booking Value'] = pd.to_numeric(df['Booking Value'], errors='coerce').fillna(0)
df['Ride Distance'] = pd.to_numeric(df['Ride Distance'], errors='coerce').fillna(0)

numeric_df = df[['Booking Value', 'Ride Distance']]

corr_matrix = numeric_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('ا')
plt.show()
plt.tight_layout()
plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Price vs. Distance')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 16
#      14 plt.show()
#      15 plt.tight_layout()
# ---> 16 plt.savefig('C:/Users/MOTA/OneDrive/Desktop/Cars Data/Price vs. Distance')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2127, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2123     dpi = getattr(self.figure, '_original_dpi', self.figure.dpi)
#    2125 # Remove the figure manager, if any, to avoid resizing the GUI widget.
#    2126 with (cbook._setattr_cm(self, manager=None),
# -> 2127       self._switch_canvas_and_return_print_method(format, backend)
#    2128          as print_method,
#    2129       cbook._setattr_cm(self.figure, dpi=dpi),
#    2130       cbook._setattr_cm(self.figure.canvas, _device_pixel_ratio=1),
#    2131       cbook._setattr_cm(self.figure.canvas, _is_saving=True),
#    2132       ExitStack() as stack):
#    2134     for prop in ["facecolor", "edgecolor"]:
#    2135         color = locals()[prop]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2028, in FigureCanvasBase._switch_canvas_and_return_print_method(self, fmt, backend)
#    2026     canvas_class = get_registered_canvas_class(fmt)
#    2027     if canvas_class is None:
# -> 2028         raise ValueError(
#    2029             "Format {!r} is not supported (supported formats: {})".format(
#    2030                 fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    2031     canvas = canvas_class(self.figure)
#    2032 canvas._is_saving = self._is_saving
#
# ValueError: Format ' distance' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff, webp)
